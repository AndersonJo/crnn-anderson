# %% [markdown]
# # Creating License Plates
#
# 아래의 링크를 clone받고 다음의 명령어를 실행 시킵니다.
#
# - [Korean-license-plate-Generator](https://github.com/qjadud1994/Korean-license-plate-Generator)
#
#
# ```
# mkdir license_plates
# python3.6 Generator_perspective.py -n 1000 -i ./license_plates/
# ```

# %% [markdown]
# # Data Sample

# %%
# %pylab inline

from torchvision import transforms
from dataset import LicensePlateDataset
from PIL import Image
from random import choice

transform = transforms.Compose([
    transforms.Resize((96, 160)),
    transforms.RandomGrayscale(0.1),
    transforms.ColorJitter(brightness=(0.2, 2), contrast=(0.3, 2), saturation=(0.2, 2), hue=(-0.3, 0.3)),
    transforms.ToTensor()
])

data = LicensePlateDataset('valid_data', transform=transform)
x, y = choice(data)
x = x.permute((1, 2, 0))
  
imshow(x.cpu().numpy())
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Output Visualization

# %%
# %pylab inline
import os
import numpy as np
from skimage.io import imread

import matplotlib.font_manager as fm
plt.rcParams['font.family'] = 'NanumGothic'


output_dir = 'output'

file_list = os.listdir(output_dir)
file_list = np.random.choice(file_list, size=16)

fig, plots = subplots(4, 4, figsize=(15, 9))
plots = plots.reshape(-1)

for i, pl in enumerate(plots):
    filename = file_list[i]
    img = imread(os.path.join(output_dir, filename))
    pl.imshow(img)
    pl.set_title(filename)
# Out:
# Populating the interactive namespace from numpy and matplotlib
